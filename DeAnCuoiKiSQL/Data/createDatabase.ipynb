# %%
# !pip install unidecode
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.5/235.5 kB 3.8 MB/s eta 0:00:00
# ...

# %%
import random
from unidecode import unidecode
import pandas as pd
import csv
import os

# %%
#Tạo bảng nhân viên

list_ho = ["Nguyễn","Trần","Lê","Bùi","Phạm","Phan","Trương","Võ","Trịnh","Khổng","Hoàng","Ông"]

list_tenlot = ["Văn","Thị","Minh","Thế","Trung","Nhật","Quang", "Mạnh","Hữu","Hoàng","Gia","Hoài","Ngọc","Anh"]

list_ten = ["An","Ân","Anh","Ánh","Bình","Bảo","Bạch","Bích","Băng","Cẩm","Châu","Chi","Cường",
            "Danh","Đức","Dung","Duyên","Diễm","Dương","Đại","Đạt","Duy","Giang","Hồng","Hà","Huỳnh","Hậu",
            "Kim","Kiều","Khanh","Khánh","Khải","Khang","Khôi","Linh","Lợi","Long","My","Mỹ","Nhi","Như","Ngọc",
            "Ngân","Nghĩa","Nhã","Minh","Oanh","Phúc","Phước","Phú","Phương","Phượng","Sơn","Sang","Sương","Uyên","Vân",
            "Vỹ","Vinh","Vy","Trang","Tiên","Thanh","Thương","Tài","Thắng","Thành","Tấn","Thịnh","Trí"]


list_diachinhanvien = ["HCM","Long An","Cần Thơ","Vĩnh Long","Trà Vinh","Nam Định","Tây Ninh","Tiền Giang","An Giang","Ninh Thuận",
               "Bình Thuận","Nha Trang","Bình Định","Phú Yên"]


list_macn = ["71LTT","230NDT","45LCT","194NTT","683THD","61BP","77HVT","206CL",
             "323DXH ","82NCT","33LVK","433LDT","46HH","35TL","10MCT","27PH",
             "27LTK","395KDV","685AC","475DBP"]


with open('nhanvien.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(["MANV", "TENNV", "MACV", "MACN", "NGAYSINH", "GIOITINH", "SODT", "EMAIL", "DIACHI", "NGAYVAO", "NGAYNGHI"])

    for i in range(8000, 8300):
        ho = random.choice(list_ho)
        tenlot = random.choice(list_tenlot)
        ten = random.choice(list_ten)
        chucVu = str(random.randint(1,17))
        chiNhanh = random.choice(list_macn)
        diachi = random.choice(list_diachinhanvien)
        sodt = str(random.randint(912345678, 977122309))
        ngaySinh = str(random.randint(1, 30)) + "/" + str(random.randint(1, 12))
        namSinh = str(random.randint(1995, 2005))

        if tenlot == "Văn":
            gioitinh = 1
        elif tenlot == "Thị":
            gioitinh = 0
        else:
            gioitinh = random.choice([1, 0])


        print(str(i), u''+ho+' '+tenlot+' '+ten, 'V'+chucVu, chiNhanh, str(ngaySinh) + "/" + str(namSinh), str(gioitinh), '0' + ""+ str(sodt),
                 unidecode(ho)+""+unidecode(tenlot)+""+unidecode(ten)+""+str(namSinh)+""+'@gmail.com', diachi,
                 str(random.randint(1,30))+"/"+str(random.randint(1,12))+"/"+str(random.randint(2020,2021)),
                 str(random.randint(1,30))+"/"+str(random.randint(1,12))+"/"+str(random.randint(2022,2023)))


        writer.writerow([str(i), u''+ho+' '+tenlot+' '+ten, chucVu, chiNhanh, str(ngaySinh) + "/" + str(namSinh), str(gioitinh), '0' + ""+ str(sodt),
                 unidecode(ho)+""+unidecode(tenlot)+""+unidecode(ten)+""+str(namSinh)+""+'@gmail.com', diachi,
                 str(random.randint(1,30))+"/"+str(random.randint(1,12))+"/"+str(random.randint(2020,2021)),
                 str(random.randint(1,30))+"/"+str(random.randint(1,12))+"/"+str(random.randint(2022,2023))])


file.close()
# Out:
# 8000 Trương Hoàng Khải V13 46HH 27/12/2000 0 0927503202 TruongHoangKhai2000@gmail.com Tây Ninh 13/10/2020 4/12/2023
# 8001 Võ Hữu Huỳnh V3 45LCT 18/3/2004 0 0947584298 VoHuuHuynh2004@gmail.com Cần Thơ 19/6/2020 5/11/2023
# 8002 Trần Văn Khang V14 82NCT 29/9/1995 1 0974521108 TranVanKhang1995@gmail.com HCM 22/5/2020 25/7/2022
# 8003 Trịnh Hữu Anh V12 71LTT 13/11/2004 0 0925693689 TrinhHuuAnh2004@gmail.com Bình Định 6/12/2020 14/8/2023
# 8004 Trần Hoài Giang V14 395KDV 26/5/1996 0 0924490986 TranHoaiGiang1996@gmail.com Vĩnh Long 25/3/2020 18/8/2023
# 8005 Bùi Hữu Vỹ V7 230NDT 20/1/2000 1 0974401318 BuiHuuVy2000@gmail.com An Giang 1/2/2021 5/10/2022
# 8006 Trương Văn Anh V4 206CL 19/9/2004 1 0936002111 TruongVanAnh2004@gmail.com Bình Định 13/6/2021 27/3/2022
# 8007 Trương Ngọc Thắng V2 33LVK 6/2/2005 1 0945714568 TruongNgocThang2005@gmail.com Vĩnh Long 3/4/2020 8/1/2022
# 8008 Bùi Trung Nhã V16 683THD 23/10/2002 0 0936447016 BuiTrungNha2002@gmail.com Nam Định 13/7/2020 4/8/2022
# ...

# %%
# Tạo Bảng chức vụ

list_tencv = ["Thu Ngân","Phục Vụ","Pha Chế","Quản Lý","Giám sát","Phụ Bếp","Bếp Chính","Nhân viên vệ sinh",
              "Chuyên viên hỗ trợ khách hàng","Chuyên viên bảo trì thiết bị","Chuyên viên phát triển sản phẩm",
              "Chuyên viên thiết kế nội thất","Quản lý sự kiện","Chuyên viên quản lý mạng xã hội","Quản lý tài chính",
              "Nhân viên giám sát ca","Chuyên viên quản lý dự án","Chuyên viên quản lý cửa hàng trực tuyến"]

with open('chucvu.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(["MACV", "TENCV"])

    for i in range(1,len(list_tencv)):

      print("V" + str(i),u''+list_tencv[i])

      writer.writerow(["V" + str(i),u''+list_tencv[i]])


file.close()
# Out:
# V1 Phục Vụ
# V2 Pha Chế
# V3 Quản Lý
# V4 Giám sát
# V5 Phụ Bếp
# V6 Bếp Chính
# V7 Nhân viên vệ sinh
# V8 Chuyên viên hỗ trợ khách hàng
# V9 Chuyên viên bảo trì thiết bị
# V10 Chuyên viên phát triển sản phẩm
# V11 Chuyên viên thiết kế nội thất
# V12 Quản lý sự kiện
# V13 Chuyên viên quản lý mạng xã hội
# V14 Quản lý tài chính
# V15 Nhân viên giám sát ca
# V16 Chuyên viên quản lý dự án
# V17 Chuyên viên quản lý cửa hàng trực tuyến

# %%
# Tạo bảng LOẠI THỨC UỐNG

list_maloaithucuong = ["CAFE","TRA","NUCE","SODA","YOUT","SITO","CHLA","DAXY","FANO","MTLT","VEOS","AFGT","CLBW","FAWT"]

list_tenLoaithucUong = ["Cà Phê","Trà","Nước ép","Soda","Yogurt","Sinh tố","Chocolate","Đá Xay",
                        "Frappuccino","Matcha Latte","Viennois","Affogato","Cold Brew","Flat White"]

with open(file_path, 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(["MALOAI","TENLOAI"])

    for i in range(len(list_maloaithucuong)):

      print(list_maloaithucuong[i],u''+list_tenLoaithucUong[i])

      writer.writerow([list_maloaithucuong[i],u''+list_tenLoaithucUong[i]])


file.close()
# Out:
# CAFE Cà Phê
# TRA Trà
# NUCE Nước ép
# SODA Soda
# YOUT Yogurt
# SITO Sinh tố
# CHLA Chocolate
# DAXY Đá Xay
# FANO Frappuccino
# MTLT Matcha Latte
# VEOS Viennois
# AFGT Affogato
# CLBW Cold Brew
# FAWT Flat White

# %%
# Tạo bảng THỨC UỐNG

list_maloaithucuong = ["CAFE","TRA","TRA","CAFE","TRA","CAFE","TRA","TRA","TRA","TRA",
                       "TRA","CAFE","CAFE","CAFE","CAFE","NUCE","SODA","YOUT","SITO","CHLA","DAXY"]

list_tentu = ["Cà phê đen đá","Trà dâu","Trà đào","Cà phê sữa","Trà đào cam sả","Bạc Xỉu",
              "Trà Đen","Trà Xanh","Trà Sen Vàng","Trà đào thạch","Trà thanh đào","Americano",
              "Latte Nóng","Cappuccino","Latte Đá","Ép Cam","Soda Bạc Hà","Yogurt Dâu","Sinh Tố Dâu",
              "Chocolate Dâu","Đá Xay Capuchino"]

list_matu = ["CFDA","TDAU","TDAO","CFSU","TDCS","BACX","TDEN","TXAN","TSVA","TDAT","TTHD","AMER",
             "LTTN","CAP","LATD","EPCA","SOBH","YOUD","STDU","CLCF","DAXC"]

with open('thucuong.csv','w',newline ='') as file:
    write = csv.writer(file)
    write.writerow(["MATU","MALOAI","TENTU","DONGIA"])

    for i in range(21):

      print(list_matu[i],list_maloaithucuong[i],u''+list_tentu[i],str(random.randint(30000,50000)))

      write.writerow([list_matu[i],list_maloaithucuong[i],u''+list_tentu[i],str(random.randint(30000,50000))])


file.close()
# Out:
# CFDA CAFE Cà phê đen đá 31798
# TDAU TRA Trà dâu 42275
# TDAO TRA Trà đào 33333
# CFSU CAFE Cà phê sữa 31715
# TDCS TRA Trà đào cam sả 42572
# BACX CAFE Bạc Xỉu 47830
# TDEN TRA Trà Đen 31047
# TXAN TRA Trà Xanh 46806
# TSVA TRA Trà Sen Vàng 48468
# TDAT TRA Trà đào thạch 49728
# TTHD TRA Trà thanh đào 44615
# AMER CAFE Americano 37731
# LTTN CAFE Latte Nóng 31722
# CAP CAFE Cappuccino 32190
# LATD CAFE Latte Đá 32494
# EPCA NUCE Ép Cam 42437
# SOBH SODA Soda Bạc Hà 33670
# YOUD YOUT Yogurt Dâu 34558
# STDU SITO Sinh Tố Dâu 44481
# CLCF CHLA Chocolate Dâu 40461
# DAXC DAXY Đá Xay Capuchino 32046

# %%
# Tạo bảng khu vực

list_makh = ["K1","K2","K3","K4","K5","K6","K7","K8","K9","K10"]
list_tenkh = ["Khu Vực 1","Khu vực 2","Khu vực 3","Khu vực 4","Khu vực 5","Khu vực 6",
              "Khu vực 7","Khu vực 8","Khu vực 9","Khu vực 10"]



with open('thucuong.csv','w',newline ='') as file:
    write = csv.writer(file)
    write.writerow(["MAKV","TENKV","HESOGIA"])

    for i in range(10):

      print(list_makh[i],u''+list_tenkh[i],str(random.randint(1,5)))

      write.writerow([list_makh[i],u''+list_tenkh[i],str(random.randint(1,5))])



file.close()
# Out:
# K1 Khu Vực 1 5
# K2 Khu vực 2 5
# K3 Khu vực 3 3
# K4 Khu vực 4 3
# K5 Khu vực 5 1
# K6 Khu vực 6 1
# K7 Khu vực 7 5
# K8 Khu vực 8 5
# K9 Khu vực 9 4
# K10 Khu vực 10 4

# %%
# Tạo bảng công thức

list_matu = ["CFDA","TDAU","TDAO","CFSU","TDCS","BACX","TDEN","TXAN","TSVA","TDAT","TTHD","AMER","LTTN","CAP"]

list_manguyenlieu = ["HCAFE","TUITRADAU","TUITRADAO","SUADAC","CAMSA","SUATUOI","TUITRADEN","BOTXANH",
                     "HATSEN","THACHDAO","DAO","HCAFEMO","SUANONG","CHCOLA","SUARICK"]

with open('congthuc.csv','w',newline ='') as file:
    write = csv.writer(file)
    write.writerow(["MATU","MANL","SOLUONG"])

    for i in range(14):

      print(list_matu[i],u''+list_manguyenlieu[i],str(random.randint(1,5)))

      write.writerow([list_matu[i],u''+list_manguyenlieu[i],str(random.randint(1,5))])


file.close()
# Out:
# CFDA HCAFE 5
# TDAU TUITRADAU 1
# TDAO TUITRADAO 2
# CFSU SUADAC 1
# TDCS CAMSA 5
# BACX SUATUOI 2
# TDEN TUITRADEN 2
# TXAN BOTXANH 2
# TSVA HATSEN 2
# TDAT THACHDAO 1
# TTHD DAO 4
# AMER HCAFEMO 3
# LTTN SUANONG 5
# CAP CHCOLA 3

# %%
# Tạo bảng chi nhánh

list_macn = ["71LTT","230NDT","45LCT","194NTT","683THD","61BP","77HVT","206CL",
             "323DXH ","82NCT","33LVK","433LDT","46HH","35TL","10MCT","27PH",
             "27LTK","395KDV","685AC","475DBP"]


list_tencn = ["71 Lý Tự Trọng","230 Nguyễn Duy Trinh","45 Lý Chính Thắng","194 Nguyễn Tất Thành","683 Trần Hưng Đạo",
              "61 Bình Phú","77 Hoàng Văn Thái","206 Cao Lỗ","323 Đỗ Xuân Hợp","82 Nguyễn Chí Thanh","33 Lê Văn Khương",
              "433 Lê Đức Thọ","46 Hoa Hồng","35 Thăng Long","10 Mai Chí Thọ","27 Phạm Hùng","27 Lý Thường Kiệt",
              "395 Kinh Dương Vương","685 Âu Cơ","475 Điện Biên Phủ"]


list_diachicn = ["Quận 1","Quận 2","Quận 3","Quận 4","Quận 5","Quận 6","Quận 7","Quận 8","Quận 9",
              "Quận 10","Quận 12","Quận Gò Vấp","Quận Phú Nhuận","Quận Tân Bình","TP Thủ Đức",
              "Huyện Bình Chánh","Huyện Hốc Môn","Quận Bình Tân","Quận Tân Phú","Quận Bình Tân"]


with open('chinhanh.csv','w',newline ='') as file:
    write = csv.writer(file)
    write.writerow(["MACN","TENCN","SODT","DIACHI","HESOGIA"])

    for i in range(20):

      print(list_macn[i],u''+list_tencn[i],'0'+str(random.randint(912345678, 977122309)),u''+list_tencn[i] + u''+list_diachicn[i],str(random.randint(1,5)))

      write.writerow([list_macn[i],u''+list_tencn[i],'0'+str(random.randint(912345678, 977122309)),
                       u''+list_tencn[i] + u''+list_diachicn[i],str(random.randint(1,5))])

file.close()
# Out:
# 71LTT 71 Lý Tự Trọng 0922314007 Quận 1 5
# 230NDT 230 Nguyễn Duy Trinh 0917932142 Quận 2 4
# 45LCT 45 Lý Chính Thắng 0963027601 Quận 3 5
# 194NTT 194 Nguyễn Tất Thành 0930632317 Quận 4 3
# 683THD 683 Trần Hưng Đạo 0927650671 Quận 5 5
# 61BP 61 Bình Phú 0969744779 Quận 6 1
# 77HVT 77 Hoàng Văn Thái 0973384511 Quận 7 1
# 206CL 206 Cao Lỗ 0947414205 Quận 8 5
# 323DXH  323 Đỗ Xuân Hợp 0974820248 Quận 9 5
# 82NCT 82 Nguyễn Chí Thanh 0970084247 Quận 10 1
# 33LVK 33 Lê Văn Khương 0945143802 Quận 12 3
# 433LDT 433 Lê Đức Thọ 0925240479 Quận Gò Vấp 3
# 46HH 46 Hoa Hồng 0942287884 Quận Phú Nhuận 2
# 35TL 35 Thăng Long 0944561912 Quận Tân Bình 3
# 10MCT 10 Mai Chí Thọ 0922812922 TP Thủ Đức 5
# 27PH 27 Phạm Hùng 0966025493 Huyện Bình Chánh 4
# 27LTK 27 Lý Thường Kiệt 0974319483 Huyện Hốc Môn 5
# 395KDV 395 Kinh Dương Vương 0944603058 Quận Bình Tân 1
# 685AC 685 Âu Cơ 0975461889 Quận Tân Phú 5
# 475DBP 475 Điện Biên Phủ 0959693575 Quận Bình Tân 1

# %%
# Tạo bảng báo cáo

list_tenbaocao = ["Báo cáo doanh thu","Báo Cáo phản hồi khách hàng","Báo cáo tuyển thêm nhân viên","Báo cáo phân tích cạnh tranh",
                  "Báo cáo chất lượng thức ăn","Báo cáo thực đơn","Báo cáo thói quen khách hàng","Báo cáo rủi ro","Báo cáo cơ hội",
                  "Báo cáo quảng cáo","Báo cáo tiếp thị","Báo cáo nhu cầu khách hàng","Báo cáo chiến lược","Báo cáo giá cả",
                  "Báo cáo hoạt động hành ngày","Báo cáo hoạt động hàng tháng","Báo cáo hoạt động hàng năm","Báo cáo doanh thu quý",
                  "Báo cáo phát triển trong tương lai","Báo cáo hiệu suất kinh doanh","Báo cáo hiệu suất làm việc"]


with open("baocao.csv",'w',newline ='') as file:
    write = csv.writer(file)
    write.writerow(["MABC","MANV","TENBC","NGAYLAP","NOIDUNG"])

    for i in range(1,20):

      print('BC'+str(i),random.randint(8000, 8651),list_tenbaocao[i],
            str(random.randint(1,30))+"/"+str(random.randint(1,12))+"/"+str(random.randint(2022,2023)))


      write.writerow(['BC'+str(i),random.randint(8000, 8651),u''+list_tenbaocao[i],
            str(random.randint(1,30))+"/"+str(random.randint(1,12))+"/"+str(random.randint(2022,2023)),'NULL'])

file.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-27-d9fb48f11e29> in <cell line: 10>()
#       8
#       9
# ---> 10 with open("/Users/Admin/Desktop/baocao.csv",'w',newline ='') as file:
#      11     write = csv.writer(file)
#      12     write.writerow(["MABC","MANV","TENBC","NGAYLAP","NOIDUNG"])
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/Admin/Desktop/baocao.csv'

# %%
import pandas as pd

list_tenbaocao = ["Báo cáo doanh thu","Báo Cáo phản hồi khách hàng","Báo cáo tuyển thêm nhân viên","Báo cáo phân tích cạnh tranh",
                  "Báo cáo chất lượng thức ăn","Báo cáo thực đơn","Báo cáo thói quen khách hàng","Báo cáo rủi ro","Báo cáo cơ hội",
                  "Báo cáo quảng cáo","Báo cáo tiếp thị","Báo cáo nhu cầu khách hàng","Báo cáo chiến lược","Báo cáo giá cả",
                  "Báo cáo hoạt động hành ngày","Báo cáo hoạt động hàng tháng","Báo cáo hoạt động hàng năm","Báo cáo doanh thu quý",
                  "Báo cáo phát triển trong tương lai","Báo cáo hiệu suất kinh doanh","Báo cáo hiệu suất làm việc"]

data = []
for i in range(1, 20):
    data.append(['BC'+str(i), random.randint(8000, 8651), list_tenbaocao[i],
                f"{random.randint(1,30)}/{random.randint(1,12)}/{random.randint(2022,2023)}",'NULL'])

df = pd.DataFrame(data, columns=["MABC","MANV","TENBC","NGAYLAP","NOIDUNG"])


df.to_csv("D:/Downloads/baocao.csv", index=False)
#df.to_csv(duong_dan_file, index=False)

print("File đã được tạo và lưu vào")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-3-e213fd3766c1> in <cell line: 17>()
#      15
#      16
# ---> 17 df.to_csv("D:/Downloads/baocao.csv", index=False)
#      18 #df.to_csv(duong_dan_file, index=False)
#      19
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3718         )
#    3719
# ...

# %%
#Tạo bảng NHACUNGCAP

list_tennhacungcap = ["Lavazza","Illy","NestleProfessional","Monin","Bunn-O-MaticCorporation",
                      "KeepCup","Bridor","LappertsIceCream","IKEA","Hario","Vinamik","NitriFood",
                      "Nestlé","C&HSugar","Bunn","Sysco","Baker'sPride","WorldMarket","UPS","FedEx"]

list_diachi = ["Quận 1","Quận 2","Quận 3","Quận 4","Quận 5","Quận 6","Quận 7","Quận 8","Quận 9",
              "Quận 10","Quận 12","Quận Gò Vấp","Quận Phú Nhuận","Quận Tân Bình","TP Thủ Đức",
              "Huyện Bình Chánh","Huyện Hốc Môn","Quận Bình Tân","Quận Tân Phú","Quận Bình Tân"]


with open('nhacungcap.csv','w',newline ='') as file:
    write = csv.writer(file)
    write.writerow(["MANCC","TENCC","SODT","EMAIL","DIACHI"])

    for i in range(1,20):

      print('C'+str(i),list_tennhacungcap[i], '0'+str(random.randint(912345678, 977122309)),list_tennhacungcap[i] + '@gmail.com',
            list_diachi[i])

      write.writerow(['C'+str(i),list_tennhacungcap[i], '0'+str(random.randint(912345678, 977122309)),
                       list_tennhacungcap[i] + '@gmail.com',u''+list_diachi[i]])

file.close()
# Out:
# C1 Illy 0941111859 Illy@gmail.com Quận 2
# C2 NestleProfessional 0924892418 NestleProfessional@gmail.com Quận 3
# C3 Monin 0914952502 Monin@gmail.com Quận 4
# C4 Bunn-O-MaticCorporation 0947716461 Bunn-O-MaticCorporation@gmail.com Quận 5
# C5 KeepCup 0961343118 KeepCup@gmail.com Quận 6
# C6 Bridor 0962077077 Bridor@gmail.com Quận 7
# C7 LappertsIceCream 0924006171 LappertsIceCream@gmail.com Quận 8
# C8 IKEA 0931753976 IKEA@gmail.com Quận 9
# C9 Hario 0938849929 Hario@gmail.com Quận 10
# C10 Vinamik 0951026700 Vinamik@gmail.com Quận 12
# C11 NitriFood 0955978275 NitriFood@gmail.com Quận Gò Vấp
# C12 Nestlé 0964184095 Nestlé@gmail.com Quận Phú Nhuận
# C13 C&HSugar 0937625076 C&HSugar@gmail.com Quận Tân Bình
# C14 Bunn 0926700265 Bunn@gmail.com TP Thủ Đức
# C15 Sysco 0932905151 Sysco@gmail.com Huyện Bình Chánh
# C16 Baker'sPride 0933878669 Baker'sPride@gmail.com Huyện Hốc Môn
# C17 WorldMarket 0971534768 WorldMarket@gmail.com Quận Bình Tân
# ...

# %%
# Bảng phiếu phụ thu

list_tenphieuphuthu = ["Phiếu phụ thu thêm đường","Phiếu phụ thu đường không đường","Phiếu phụ thu sữa tươi",
                       "Phiếu phụ thu sữa hạnh nhân","Phiếu phụ thu sữa đậu nành","Phiếu phụ thu gia vị đặc biệt",
                       "Phiếu phụ thu nước đá","Phiếu phụ thu size lớn hơn","Phiếu phụ thu thêm espresso","Phiếu phụ thu topping",
                       "Phiếu phụ thu đặc biệt đối với đồ uống hỗn hợp","Phiếu phụ thu đổi loại sữa","Phiếu phụ thu topping kem phô mai",
                       "Phiếu phụ thu đá xay thêm","Phiếu phụ thu chất béo cao","Phiếu phụ thu topping hạt dẻ",
                       "Phiếu phụ thu đồ uống không đường mà sử dụng thêm sữa","Phiếu phụ thu nguyên liệu hữu cơ","Phiếu phụ thu mùi vị thêm",
                       "Phiếu phụ thu thêm lớp kem phía trên","Phiếu phụ thu đồ uống gần như không đường"]


with open('phieuphuthu.csv','w',newline ='') as file:
    write = csv.writer(file)
    write.writerow(["MAPHIEUPT","MANV","TENPPT","NGAYLAP","SOTIEN"])

    for i in range(1,21):

      print('MAPT'+str(i),str(random.randint(8000,8600)),list_tenphieuphuthu[i],
            str(random.randint(1,30))+"/"+str(random.randint(1,12))+"/"+str(random.randint(2022,2023)),
            str(random.randint(10000,30000)))


      write.writerow(['MAPT'+str(i),str(random.randint(8000,8600)),u''+list_tenphieuphuthu[i],
            str(random.randint(1,30))+"/"+str(random.randint(1,12))+"/"+str(random.randint(2022,2023)),
            str(random.randint(10000,30000))])

file.close()
# Out:
# MAPT1 8427 Phiếu phụ thu đường không đường 4/11/2023 16517
# MAPT2 8102 Phiếu phụ thu sữa tươi 30/3/2022 15797
# MAPT3 8171 Phiếu phụ thu sữa hạnh nhân 23/3/2022 14002
# MAPT4 8434 Phiếu phụ thu sữa đậu nành 16/2/2022 11491
# MAPT5 8228 Phiếu phụ thu gia vị đặc biệt 6/4/2023 11827
# MAPT6 8438 Phiếu phụ thu nước đá 7/8/2023 27031
# MAPT7 8546 Phiếu phụ thu size lớn hơn 9/4/2022 23764
# MAPT8 8599 Phiếu phụ thu thêm espresso 23/2/2023 17850
# MAPT9 8023 Phiếu phụ thu topping 3/6/2022 20772
# MAPT10 8506 Phiếu phụ thu đặc biệt đối với đồ uống hỗn hợp 20/1/2023 24388
# MAPT11 8294 Phiếu phụ thu đổi loại sữa 17/4/2023 26824
# MAPT12 8181 Phiếu phụ thu topping kem phô mai 21/5/2022 16912
# MAPT13 8435 Phiếu phụ thu đá xay thêm 29/12/2022 17338
# MAPT14 8446 Phiếu phụ thu chất béo cao 4/2/2023 10526
# MAPT15 8439 Phiếu phụ thu topping hạt dẻ 15/10/2023 12277
# MAPT16 8490 Phiếu phụ thu đồ uống không đường mà sử dụng thêm sữa 13/10/2022 14580
# ...

# %%
# Tạo bảng phiếu chi

list_noidungchi = ["Sữa và đường","Cà phê và nguyên liệu pha chế","Siro và nước hoa quả","Thực phẩm nhẹ và bánh ngọt",
                   "Thực phẩm tươi và nguyên liệu","Thiết bị và đồ dùng pha chế","Nhân viên và tiền lương","Vận chuyển và lưu trữ hàng hóa",
                   "Tiền thuê và chi phí vận hành quán","Tiền mặt hàng tiêu hao","Chi phí tiếp thị và quảng cáo","Chi phí mẫu thử và sáng tạo",
                   "Bảo hiểm và chi phí pháp lý","Chi phí vận chuyển và giao hàng","Bảo hiểm và chi phí pháp lý","Chi phí vận chuyển và giao hàng",
                   "Dịch vụ tiếp khách và tiêu dùng tại chỗ","Chi phí cơ bản và lãi suất","Chi phí điều hành và quản lý","Chi phí đào tạo nhân viên",
                   "Chi phí khác","Lợi nhuận hoặc lỗ"]


with open('phieuchi.csv','w',newline ='') as file:
    write = csv.writer(file)
    write.writerow(["MAPC","MANV","NOIDUNGCHI","NGAYLAP","TONGTIEN"])

    for i in range(1,21):

      print('MAPC'+str(i),str(random.randint(8000,8600)),list_noidungchi[i],
            str(random.randint(1,30))+"/"+str(random.randint(1,12))+"/"+str(random.randint(2022,2023)),
            str(random.randint(100000,1000000)))


      write.writerow(['MAPC'+str(i),str(random.randint(8000,8600)),u''+list_noidungchi[i],
            str(random.randint(1,30))+"/"+str(random.randint(1,12))+"/"+str(random.randint(2022,2023)),
            str(random.randint(100000,1000000))])

file.close()
# Out:
# MAPC1 8120 Cà phê và nguyên liệu pha chế 13/3/2022 214418
# MAPC2 8370 Siro và nước hoa quả 30/8/2023 361266
# MAPC3 8077 Thực phẩm nhẹ và bánh ngọt 26/7/2023 415516
# MAPC4 8466 Thực phẩm tươi và nguyên liệu 18/7/2022 885545
# MAPC5 8305 Thiết bị và đồ dùng pha chế 23/11/2022 637522
# MAPC6 8047 Nhân viên và tiền lương 30/5/2023 650798
# MAPC7 8237 Vận chuyển và lưu trữ hàng hóa 5/3/2023 802497
# MAPC8 8523 Tiền thuê và chi phí vận hành quán 20/4/2022 650858
# MAPC9 8224 Tiền mặt hàng tiêu hao 11/9/2023 933915
# MAPC10 8002 Chi phí tiếp thị và quảng cáo 7/11/2022 149632
# MAPC11 8504 Chi phí mẫu thử và sáng tạo 25/9/2022 690259
# MAPC12 8136 Bảo hiểm và chi phí pháp lý 7/5/2022 768373
# MAPC13 8210 Chi phí vận chuyển và giao hàng 8/1/2022 677039
# MAPC14 8163 Bảo hiểm và chi phí pháp lý 7/2/2023 770360
# MAPC15 8276 Chi phí vận chuyển và giao hàng 8/3/2023 717489
# MAPC16 8469 Dịch vụ tiếp khách và tiêu dùng tại chỗ 29/2/2023 177449
# ...

# %%
# Tạo Bảng phiếu nhập

# list_noidungnhap = ["Cà phê hạt","Sữa","Đường","Siro","Syrup","Thực phẩm và nguyên liệu pha chế","Thực phẩm nhẹ và bánh ngọt",
#                     "Rau cải và hoa quả tươi","Nguyên liệu cho thực đơn","Nước đóng chai và nước đóng lon","Thực phẩm đóng hộp và đóng túi",
#                     "Đồ uống đóng chai và đóng lon","Mực in và giấy in","Đồ dùng và thiết bị phục vụ","Vật liệu vệ sinh và lau chùI",
#                     "Hương liệu và gia vị","Bộ sưu tập đồ trang trí và nội thất","Dụng cụ và thiết bị làm bánh","Dụng cụ và thiết bị pha chế",
#                     "Đồ trang trí và vật liệu quảng cáo","Vật liệu và dụng cụ tiếp khách"]


with open('phieunhap.csv','w',newline ='') as file:
    write = csv.writer(file)
    write.writerow(["MAPN","MANV","MANCC","NGAYLAP","TONGTIEN"])

    for i in range(1,21):

      print('MAPN'+str(i),str(random.randint(8000,8600)),'C'+ str(i),
            str(random.randint(1,30))+"/"+str(random.randint(1,12))+"/"+str(random.randint(2022,2023)),
            str(random.randint(1000000,5000000)))


      write.writerow(['MAPN'+str(i),str(random.randint(8000,8600)),'C'+ str(i),
            str(random.randint(1,30))+"/"+str(random.randint(1,12))+"/"+str(random.randint(2022,2023)),
            str(random.randint(1000000,5000000))])


file.close()
# Out:
# MAPN1 8036 C1 28/12/2023 3374330
# MAPN2 8495 C2 29/3/2023 1937546
# MAPN3 8233 C3 12/3/2023 3603404
# MAPN4 8184 C4 16/8/2023 4071695
# MAPN5 8212 C5 1/1/2023 1478101
# MAPN6 8322 C6 19/12/2022 4710065
# MAPN7 8510 C7 28/10/2023 2293711
# MAPN8 8254 C8 5/2/2022 4784945
# MAPN9 8584 C9 25/1/2022 3062201
# MAPN10 8274 C10 13/12/2023 3233069
# MAPN11 8199 C11 26/9/2022 1571103
# MAPN12 8552 C12 5/11/2022 4540219
# MAPN13 8350 C13 25/10/2023 2912335
# MAPN14 8541 C14 16/2/2023 1905856
# MAPN15 8305 C15 7/8/2023 3734901
# MAPN16 8013 C16 22/7/2023 3453418
# MAPN17 8222 C17 1/7/2022 4069254
# MAPN18 8011 C18 15/9/2023 1205491
# MAPN19 8443 C19 17/10/2022 2635535
# MAPN20 8524 C20 10/7/2023 3039521

# %%
# Tạo Bảng Hóa Đơn

# list_makh = ["K1","K2","K3","K4","K5","K6","K7","K8","K9","K10"]


with open('hoadon.csv','w',newline ='') as file:
    write = csv.writer(file)
    write.writerow(["MAHD","MANV","MAKV","NGAYLAP","TONGTIEN"])

    for i in range(1,100):

      khuvuc = random.choice(list_makh)

      print('HD'+str(i),str(random.randint(8000,8600)),khuvuc,
            str(random.randint(1,30))+"/"+str(random.randint(1,12))+"/"+str(random.randint(2022,2023)),
            str(random.randint(50000,500000)))


      write.writerow(['HD'+str(i),str(random.randint(8000,8600)),khuvuc,
            str(random.randint(1,30))+"/"+str(random.randint(1,12))+"/"+str(random.randint(2022,2023)),
            str(random.randint(50000,500000))])


file.close()
# Out:
# HD1 8404 K2 18/7/2023 99390
# HD2 8316 K1 20/1/2022 261352
# HD3 8016 K3 14/3/2023 348535
# HD4 8111 K7 4/6/2023 310605
# HD5 8475 K7 25/12/2022 292832
# HD6 8493 K2 9/9/2023 357038
# HD7 8311 K9 14/3/2023 443768
# HD8 8277 K9 20/8/2023 170360
# HD9 8488 K1 28/3/2022 107865
# HD10 8448 K8 23/2/2022 413250
# HD11 8531 K6 3/11/2023 228700
# HD12 8446 K2 30/7/2023 436266
# HD13 8314 K8 22/6/2023 296927
# HD14 8014 K3 2/5/2023 472546
# HD15 8313 K5 28/7/2023 491551
# HD16 8325 K2 22/6/2022 432024
# HD17 8346 K10 27/9/2023 192817
# HD18 8339 K5 13/1/2022 449583
# HD19 8116 K2 25/5/2023 82143
# HD20 8387 K4 17/1/2022 123726
# HD21 8498 K9 14/11/2022 346433
# HD22 8553 K4 14/10/2022 333597
# HD23 8524 K3 16/7/2023 491583
# HD24 8407 K8 24/1/2022 159264
# HD25 8508 K4 14/11/2022 174575
# HD26 8000 K10 2/6/2023 326573
# HD27 8374 K1 28/8/2023 88721
# HD28 8150 K8 19/1/2023 220147
# HD29 8218 K2 30/11/2023 100613
# HD30 8342 K7 4/6/2023 338209
# HD31 8291 K5 17/3/2022 200199
# ...

# %%
# Tạo Bảng Chi Tiết Hóa Đơn

list_matu = ["CFDA","TDAU","TDAO","CFSU","TDCS","BACX","TDEN","TXAN","TSVA","TDAT","TTHD","AMER","LTTN","CAP"]


with open('chitiet_hoadon.csv','w',newline ='') as file:
    write = csv.writer(file)
    write.writerow(["MATU","MAHD","SOLUONG"])

    for i in range(1,100):

      matu = random.choice(list_matu)

      print(matu,'HD'+ str(random.randint(1,100)), str(random.randint(1,10)))

      write.writerow([matu,'HD'+ str(random.randint(1,50)), str(random.randint(1,10))])



file.close()
# Out:
# CFDA HD17 10
# TTHD HD36 9
# TDAU HD4 1
# TDAT HD34 3
# LTTN HD36 6
# CAP HD19 3
# TDEN HD29 2
# CFDA HD46 10
# TTHD HD12 1
# TDAT HD41 8
# TSVA HD49 10
# TDAO HD5 8
# CFDA HD38 8
# TDAT HD20 1
# TDCS HD20 1
# TDCS HD43 6
# BACX HD47 5
# TDEN HD30 2
# TSVA HD43 1
# TTHD HD17 4
# TDCS HD14 3
# CFDA HD8 10
# TDAO HD7 8
# AMER HD46 4
# BACX HD44 7
# AMER HD45 5
# TDAO HD23 8
# TDCS HD38 9
# LTTN HD31 3
# CAP HD12 7
# CAP HD22 9
# TDAT HD27 4
# TDCS HD5 2
# TTHD HD20 9
# CFSU HD32 3
# CFDA HD16 4
# TDAU HD37 4
# BACX HD15 9
# TSVA HD32 2
# LTTN HD11 9
# CFSU HD50 3
# BACX HD33 7
# TDEN HD40 10
# TTHD HD45 1
# TDAU HD18 3
# TTHD HD15 10
# AMER HD35 5
# CFDA HD26 10
# LTTN HD33 4

# %%
# Tạo Bảng Chi Tiết Phiếu Nhập

list_manguyenlieu = ["HCAFE","TUITRADAU","TUITRADAO","SUADAC","CAMSA","SUATUOI","TUITRADEN","BOTXANH",
                     "HATSEN","THACHDAO","DAO","HCAFEMO","SUANONG","CHCOLA","SUARICK"]



with open('chitiet_phieunhap.csv','w',newline ='') as file:
    write = csv.writer(file)
    write.writerow(["MANL","MAPN","SOLUONG"])

    for i in range(1,100):

      manguyenlieu = random.choice(list_manguyenlieu)

      print(manguyenlieu,'MAPN'+ str(random.randint(1,20)), str(random.randint(1,100)))


      write.writerow([manguyenlieu,'MAPN'+ str(random.randint(1,20)), str(random.randint(1,100))])


file.close()
# Out:
# BOTXANH MAPN1 60
# TUITRADAO MAPN3 68
# HCAFEMO MAPN15 69
# CAMSA MAPN5 93
# TUITRADEN MAPN8 4
# HCAFE MAPN12 16
# SUARICK MAPN7 50
# CHCOLA MAPN11 98
# CHCOLA MAPN19 41
# HATSEN MAPN2 75
# SUANONG MAPN6 31
# TUITRADAO MAPN17 26
# CHCOLA MAPN4 71
# DAO MAPN4 79
# CHCOLA MAPN3 61
# SUANONG MAPN4 88
# HATSEN MAPN16 42
# SUARICK MAPN17 31
# TUITRADAO MAPN16 12
# SUARICK MAPN10 100
# CAMSA MAPN6 23
# CHCOLA MAPN10 38
# CAMSA MAPN4 6
# CAMSA MAPN17 43
# SUATUOI MAPN6 38
# CHCOLA MAPN13 82
# TUITRADAO MAPN13 28
# HATSEN MAPN5 65
# HATSEN MAPN20 63
# SUARICK MAPN18 33
# HCAFEMO MAPN4 66
# SUATUOI MAPN8 12
# SUARICK MAPN15 38
# SUATUOI MAPN1 59
# THACHDAO MAPN8 35
# SUATUOI MAPN9 40
# CAMSA MAPN9 84
# HATSEN MAPN1 8
# SUARICK MAPN16 14
# SUANONG MAPN5 29
# SUADAC MAPN17 52
# CAMSA MAPN16 53
# SUADAC MAPN20 53
# DAO MAPN14 68
# TUITRADEN MAPN18 51
# TUITRADAO MAPN8 82
# CAMSA MAPN16 30
# SUADAC MAPN2 43
# HCAFEMO MAPN15 88

# %%
# TẠO BẢNG NGUYÊN LIỆU


list_manguyenlieu = ["HCAFE","TUITRADAU","TUITRADAO","SUADAC","CAMSA","SUATUOI","TUITRADEN","BOTXANH",
                     "HATSEN","THACHDAO","DAO","HCAFEMO","SUANONG","CHCOLA","SUARICK"]

list_tenNguyenLieu = ["Hạt Cafe","Túi trà dâu","Túi trà đào","Sữa đặc","Cam sả","Sữa tươi","Túi trà đen",
                      "Bột Xanh","Hạt sen","Thạch đào","Đào","Hạt Cafe Moka","Sữa nóng","Chocolase","Sữa béo"]

list_donVi = ["Bịch","Túi","Túi","Lon","Trái","Hộp","Túi","Túi","Hộp","Hộp","Hộp","Bịch","Lon","Chai","Hộp"]


with open('nguyenlieu.csv','w',newline ='') as file:
    write = csv.writer(file)
    write.writerow(["MANL","TENNL","SOLUONG","DONVI"])

    for i in range(1,14):

      print(list_manguyenlieu[i],list_tenNguyenLieu[i], str(random.randint(1,100)),list_donVi[i])

      write.writerow([list_manguyenlieu[i],u''+list_tenNguyenLieu[i], str(random.randint(1,100)),u''+list_donVi[i]])


file.close()
# Out:
# TUITRADAU Túi trà dâu 95 Túi
# TUITRADAO Túi trà đào 28 Túi
# SUADAC Sữa đặc 53 Lon
# CAMSA Cam sả 33 Trái
# SUATUOI Sữa tươi 52 Hộp
# TUITRADEN Túi trà đen 13 Túi
# BOTXANH Bột Xanh 48 Túi
# HATSEN Hạt sen 94 Hộp
# THACHDAO Thạch đào 5 Hộp
# DAO Đào 81 Hộp
# HCAFEMO Hạt Cafe Moka 66 Bịch
# SUANONG Sữa nóng 64 Lon
# CHCOLA Chocolase 22 Chai
